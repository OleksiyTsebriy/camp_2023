# %% [markdown]
# <font color= 'green' size =4>
#
# # Working Environment
# </font>

# %% [markdown]
# # Content
#
# - python
# - virtual env
# - conda
# - jupyter notebook
# - jupyter lab
# - environment on docker
# - colab
# - pycharm
# - python cources
# - types
# - list comperhensions
# - home task

# %% [markdown]
# # Python
#
# Python is an `interpreted`, high-level, general-purpose programming language, created by Guido van Rossum and first released in 1991.
#
# Python 2 language was officially discontinued in 2020.
# `Python 3` was released on 2008 is still actual and supported.
#
# You may have **several python interpreters on the same machine**.
#
# There are following approaches of installing python:
# - python interpreter on local machine
# - python interpreter of virtual environment on local machine
# - (python interpreter of conda or conda virtual environment on local machine)
# - python interpreter of docker container
# - Google colab
# - etc.

# %% [markdown]
# ## Python interpreter on local machine
#
# [python.org](https://www.python.org/downloads/)
# ```
# OleksiyTsebriys-MacBook-Pro:bin otsebriy$ which python
# /usr/bin/python
# OleksiyTsebriys-MacBook-Pro:bin otsebriy$ python -V
# Python 2.7.16
#
# OleksiyTsebriys-MacBook-Pro:~ otsebriy$ cd /usr/bin
# OleksiyTsebriys-MacBook-Pro:bin otsebriy$ python + double tab
# python            python2.7-config  python3.8         pythonw2.7
# python-config     python3           python3.8-config
# python2.7         python3-config    pythonw
#
# OleksiyTsebriys-MacBook-Pro:bin otsebriy$ python3 -V
# Python 3.8.3
# ```
#
# **Python 2** may get installed by default though there is python 3 as well

# %% [markdown]
# ## Check version

# %%
# !python -V

# python --version
# Out:
# Python 3.7.7

# %% [markdown]
# ## Check which python

# %%
# !which python
# Out:
# /Users/otsebriy/opt/anaconda3/envs/ot_env/bin/python

# %% [markdown]
# ## Determine python version dynamically

# %%
import platform
platform.python_version()
# Out:
# '3.7.7'

# %% [markdown]
# ## `Pip` for installing and uninstalling  new packages
#
# ### Check pip version

# %%
# !pip -V
# Out:
# pip 20.0.2 from /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pip (python 3.7)

# %% [markdown]
# #### Note: this pip is not the same as on terminal with no virtual env
# It works even without `!`

# %%
pip -V
# Out:
# pip 20.0.2 from /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pip (python 3.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### From local interpreter:
# ```
# $ pip -V
# -bash: pip: command not found
# $ pip3 -V
# pip 19.2.3 from /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pip (python 3.8)
# ```

# %% [markdown]
# #### Note: pip is not the same as pip3

# %%
# !pip3 -V
# Out:
# pip 19.2.3 from /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pip (python 3.8)

# %% [markdown]
# ### Which  pip

# %%
# !which pip
# Out:
# /Users/otsebriy/opt/anaconda3/envs/ot_env/bin/pip

# %% [markdown]
# #### Note: Be careful with python version
# above is from (conda) virtual env `ot_env` whereas pip3 (following) pertains to local interpreter

# %%
# !which pip3
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/bin/pip3

# %% [markdown]
# ## Install/Update package

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages (1.0.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %% [markdown]
# #### Note: You may specify version to install
#
#     pip install 'pandas==0.23.4'
#     pip install pandas==0.23.2

# %% [markdown]
# #### From local interpreter
# ```
# pip install pandas
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/site-packages (0.25.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/site-packages (from pandas) (1.17.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
# ```

# %% [markdown]
# ## Install all requirements from the file
#     pip install -r requirements.txt

# %% [markdown]
# ##  Uninstall packages

# %%
pip uninstall pandas
# Out:
# Found existing installation: pandas 1.0.3
# Uninstalling pandas-1.0.3:
#   Would remove:
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas-1.0.3.dist-info/*
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/*
#   Would not remove (might be manually added):
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/_libs/skiplist.cpython-37m-darwin.so
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/_libs/window.cpython-37m-darwin.so
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/compat/chainmap_impl.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/computation/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/computation/expressions.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/categorical.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/config.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/datetools.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/internals.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/ops.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/panel.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/sparse/array.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/sparse/frame.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/sparse/scipy_sparse.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/sparse/series.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/core/window.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/formats/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/formats/style.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/clipboard/clipboards.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/clipboard/exceptions.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/clipboard/windows.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/excel.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/formats/terminal.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/json/json.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/json/normalize.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/json/table_schema.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/msgpack/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/msgpack/_packer.cpython-37m-darwin.so
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/msgpack/_unpacker.cpython-37m-darwin.so
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/msgpack/_version.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/msgpack/exceptions.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/io/packers.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/json.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/lib.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/parser.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/plotting/_compat.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/plotting/_converter.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/plotting/_style.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/plotting/_timeseries.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/plotting/_tools.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/common.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/conftest.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_algos.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_analytics.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_api.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_constructors.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_dtypes.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_indexing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_missing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_operators.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_repr.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_sorting.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_subclass.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/categorical/test_warnings.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/dtypes/test_cast.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/extension/category/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/extension/category/test_categorical.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_asof.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_convert_to.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_indexing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_quantile.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_rank.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_replace.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/frame/test_sorting.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/generic/test_panel.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/datetimes/test_arithmetic.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/datetimes/test_construction.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/interval/test_construction.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/interval/test_interval_new.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/period/test_arithmetic.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/period/test_construction.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/test_category.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/test_multi.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/test_range.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/timedeltas/test_arithmetic.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexes/timedeltas/test_construction.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexing/test_ix.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexing/test_multiindex.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/indexing/test_panel.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/common.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_buffer.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_case.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_except.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_extension.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_format.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_limits.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_newspec.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_obj.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_pack.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_read_size.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_seq.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_sequnpack.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_subtype.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_unpack.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/msgpack/test_unpack_raw.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/c_parser_only.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/comment.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/common.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/compression.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/converters.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/dialect.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/dtypes.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/header.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/index_col.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/mangle_dupes.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/multithread.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/na_values.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/parse_dates.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/python_parser_only.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/quoting.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/skiprows.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/test_parsers.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/parser/usecols.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/test_excel.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/test_packers.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/io/test_pytables.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/plotting/test_deprecated.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/reshape/test_tile.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/scalar/timedelta/test_construction.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/common.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/indexing/conftest.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/test_asof.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/test_quantile.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/test_rank.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/test_replace.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/series/test_sorting.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/common.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/test_analytics.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/test_apply.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/test_frame.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/test_indexing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/test_to_csv.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/frame/test_to_from_scipy.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/series/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/series/test_indexing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/series/test_series.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_arithmetics.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_array.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_combine_concat.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_format.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_groupby.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_indexing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_libsparse.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_pivot.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/sparse/test_reshape.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/test_base.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/test_config.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/test_panel.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/test_resample.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/test_window.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/tseries/conftest.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/tseries/test_frequencies.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/tseries/test_holiday.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tests/util/test_testing.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tools/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tools/merge.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tools/plotting.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tseries/converter.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tseries/plotting.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/tslib.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/types/__init__.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/types/common.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/types/concat.py
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/util/_move.cpython-37m-darwin.so
#     /Users/otsebriy/opt/anaconda3/envs/ot_env/lib/python3.7/site-packages/pandas/util/decorators.py
# Proceed (y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Review installed packages

# %%
pip list

# %%
pip freeze
# Out:
# absl-py==0.9.0
# aiofiles==0.5.0
# aiohttp==3.6.2
# alabaster==0.7.12
# amazonwebservices==0.0.2
# anaconda-client==1.7.2
# anaconda-project==0.8.3
# aniso8601==7.0.0
# appnope==0.1.0
# appscript==1.0.1
# apyori==1.1.2
# asn1crypto==1.3.0
# astor==0.8.0
# astroid==2.3.3
# astropy==4.0
# async-exit-stack==1.0.1
# async-generator==1.10
# async-timeout==3.0.1
# atomicwrites==1.3.0
# attrs==19.3.0
# Authlib==0.14.1
# azure-common==1.1.25
# azure-storage-blob==2.1.0
# azure-storage-common==2.1.0
# Babel==2.8.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.8.2
# bitarray==1.2.1
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.4.0
# boto==2.49.0
# boto3==1.12.17
# botocore==1.15.17
# Bottleneck==1.3.2
# bqplot==0.12.4
# bs4==0.0.1
# cachetools==4.0.0
# certifi==2020.12.5
# cffi==1.14.0
# chardet==3.0.4
# Click==7.0
# cloudpickle==1.3.0
# clyent==1.2.2
# colorama==0.4.3
# contextlib2==0.6.0.post1
# cryptography==2.8
# cycler==0.10.0
# Cython==0.29.15
# cytoolz==0.10.1
# dask==2.11.0
# decorator==4.4.1
# deepcrawl==0.0.1
# defusedxml==0.6.0
# distributed==2.11.0
# dnspython==1.16.0
# docutils==0.16
# email-validator==1.1.1
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastapi==0.55.1
# fastcache==1.1.0
# filelock==3.0.12
# Flask==1.1.1
# fsspec==0.6.2
# gast==0.2.2
# gevent==1.4.0
# git-remote-codecommit==1.13
# glob2==0.7
# gmpy2==2.0.8
# google-api-core==1.16.0
# google-api-python-client==1.7.11
# google-auth==1.11.2
# google-auth-httplib2==0.0.3
# google-cloud-automl==1.0.1
# google-cloud-core==1.3.0
# google-cloud-language==1.3.0
# google-cloud-storage==1.28.1
# google-cloud-vision==1.0.0
# google-pasta==0.2.0
# google-resumable-media==0.5.0
# googleapis-common-protos==1.51.0
# googleservices==0.0.4
# graphene==2.1.8
# graphql-core==2.3.2
# graphql-relay==2.0.1
# greenlet==0.4.15
# grpcio==1.27.2
# h11==0.9.0
# h5py==2.10.0
# HeapDict==1.0.1
# html5lib==1.0.1
# httplib2==0.17.0
# httptools==0.1.1
# hypothesis==5.5.4
# idna==2.9
# ijson==2.6.1
# imageio==2.6.1
# imagesize==1.2.0
# importlib-metadata==1.5.0
# ipykernel==5.1.4
# ipython==7.12.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# iso8601==0.1.12
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.16.0
# Jinja2==2.11.1
# jmespath==0.9.5
# joblib==0.14.1
# json5==0.9.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==6.1.0
# jupyter-core==4.6.1
# jupyterlab==1.2.6
# jupyterlab-server==1.0.6
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keyring==21.1.0
# kiwisolver==1.1.0
# kwfinder==0.0.8
# lazy-object-proxy==1.4.3
# libarchive-c==2.8
# lief==0.9.0
# llvmlite==0.31.0
# locket==0.2.0
# lxml==4.5.0
# majestic==0.0.2
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib==3.1.3
# mccabe==0.6.1
# mistune==0.8.4
# mkl-fft==1.0.15
# mkl-random==1.1.0
# mkl-service==2.3.0
# mock==4.0.1
# more-itertools==8.2.0
# mpmath==1.1.0
# msgpack==0.6.1
# multidict==4.7.5
# multipledispatch==0.6.0
# nbconvert==5.6.1
# nbformat==5.0.4
# nest-asyncio==1.3.2
# networkx==2.4
# nltk==3.4.5
# nose==1.3.7
# notebook==6.0.3
# numba==0.48.0
# numexpr==2.7.1
# numpy==1.18.1
# numpydoc==0.9.2
# oauth2client==4.1.3
# olefile==0.46
# opencv-python==4.2.0.34
# openpyxl==3.0.3
# opt-einsum==3.1.0
# orjson==3.0.2
# oscrypto==1.2.0
# packaging==20.1
# pandas==1.0.3
# pandocfilters==1.4.2
# parso==0.6.1
# partd==1.1.0
# path==13.1.0
# pathlib2==2.3.5
# patsy==0.5.1
# pendo==0.0.4
# pep8==1.7.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.0.0
# pkginfo==1.5.0.1
# pluggy==0.13.1
# ply==3.11
# prometheus-client==0.7.1
# promise==2.3
# prompt-toolkit==3.0.3
# protobuf==3.11.4
# psutil==5.6.7
# psycopg2==2.8.5
# ptyprocess==0.6.0
# py==1.8.1
# pyarrow==0.16.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycryptodomex==3.9.7
# pycurl==7.43.0.5
# pydantic==1.5.1
# pyflakes==2.1.1
# Pygments==2.5.2
# PyJWT==1.7.1
# pylint==2.4.4
# PyMySQL==0.9.2
# pyodbc===4.0.0-unsupported
# pyOpenSSL==19.1.0
# pyparsing==2.4.6
# pyrsistent==0.15.7
# PySocks==1.7.1
# pytest==5.3.5
# pytest-arraydiff==0.3
# pytest-astropy==0.8.0
# pytest-astropy-header==0.1.2
# pytest-doctestplus==0.5.0
# pytest-openfiles==0.4.0
# pytest-remotedata==0.3.2
# python-dateutil==2.8.1
# python-multipart==0.0.5
# pytz==2019.3
# PyWavelets==1.1.1
# PyYAML==5.3
# pyzmq==18.1.1
# QtAwesome==0.6.1
# qtconsole==4.6.0
# QtPy==1.9.0
# readable==0.0.1
# requests==2.23.0
# rope==0.16.0
# rsa==4.0
# ruamel-yaml==0.15.87
# Rx==1.6.1
# s3transfer==0.3.3
# salesforce==0.0.3
# salesforce-bulk==2.1.0
# scikit-image==0.16.2
# scikit-learn==0.22.1
# scipy==1.4.1
# seaborn==0.10.0
# searchlight==0.2.5
# searchlight-api==1.0.0
# selenium==3.141.0
# semrush==0.0.5
# Send2Trash==1.5.0
# simple-salesforce==0.75.3
# simplegeneric==0.8.1
# simplejson==3.17.0
# singledispatch==3.4.0.3
# six==1.14.0
# slack==0.0.2
# slackclient==1.2.1
# snowballstemmer==2.0.0
# snowflake==0.0.1
# snowflake-connector-python==2.2.1
# snowflake-sqlalchemy==1.2.1
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# soupsieve==1.9.5
# Sphinx==2.4.0
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.2.0
# spyder==3.3.6
# spyder-kernels==0.5.2
# SQLAlchemy==1.3.16
# starlette==0.13.2
# statsmodels==0.11.0
# sympy==1.5.1
# tableau==0.0.1
# tables==3.6.1
# tblib==1.6.0
# tensorboard==2.0.0
# tensorflow==2.0.0
# tensorflow-estimator==2.0.0
# tensorflow-hub==0.8.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# toolz==0.10.0
# tornado==6.0.3
# totango==0.0.2
# tqdm==4.42.1
# traitlets==4.3.3
# traittypes==0.2.1
# ujson==2.0.3
# unicodecsv==0.14.1
# uritemplate==3.0.1
# urllib3==1.25.8
# uvicorn==0.11.5
# uvloop==0.14.0
# vertifire==0.0.2
# wcwidth==0.1.8
# webencodings==0.5.1
# webpagetest==0.0.1
# websocket-client==0.57.0
# websockets==8.1
# Werkzeug==1.0.0
# widgetsnbextension==3.5.1
# wrapt==1.11.2
# wrike==0.0.1
# wurlitzer==2.0.0
# xgboost==1.3.0
# xlrd==1.2.0
# XlsxWriter==1.2.7
# xlwings==0.17.1
# xlwt==1.3.0
# xmltodict==0.12.0
# yarl==1.4.2
# zict==1.0.0
# zipp==2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ###  Note:
#
# You may get `pip` as well as `python` set default to `python 2`, thus you may need to use `pip3` and `python3` commands

# %%
# !pip3 freeze
# Out:
# aws-google-auth==0.0.36
# beautifulsoup4==4.9.1
# boto3==1.14.38
# botocore==1.17.38
# certifi==2020.6.20
# chardet==3.0.4
# configparser==5.0.0
# docutils==0.15.2
# filelock==3.0.12
# git-remote-codecommit==1.15.1
# idna==2.10
# jmespath==0.10.0
# keyring==21.3.0
# keyrings.alt==3.4.0
# lxml==4.5.2
# Pillow==7.2.0
# python-dateutil==2.8.1
# pytz==2020.1
# requests==2.24.0
# s3transfer==0.3.3
# six==1.15.0
# soupsieve==2.0.1
# tabulate==0.8.7
# tzlocal==2.1
# urllib3==1.25.10

# %% [markdown]
# ### Python interpreter of virtual environment on local machine
#
# Virtual environment:
# - allows to define necessary python interpreter
# - install necessary packages for specified task

# %% [markdown]
# `pip install virtualenv`
#
# `virtualenv new_env`
#
# `source new_env/bin/activate`
#
# ```
# (new_env)... $ pip --version
# pip 18.1 from .../virtual_environments/.../pip (python 3.6)`
# $ pip list
#         Package    Version
#         ---------- -------
#         pip        18.1
#         setuptools 40.6.2
#         wheel      0.32.3
# ```
#
# `deactivate`
#
# Note: Activate virtual env for windows
#
# `$ ./Scripts/activate`

# %% [markdown]
# ## Conda
#
# Facilitates installing standard packages used in scientific computing without having to worry about their dependencies.
#
# [conda documentation](https://docs.conda.io/projects/conda/en/latest/user-guide/install/download.html)
#
# Installers:
# * [Anaconda](https://www.anaconda.com/products/individual)  includes lots of packages
# * [Miniconda](https://docs.conda.io/en/latest/miniconda.html) allows to use `conda` command to install necessary packages etc.
#
# via terminal sample:
# ```
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-x86_64.sh -O ~/miniconda.sh
# bash ~/miniconda.sh -b -p $HOME/miniconda```

# %% [markdown]
# ### Check conda version

# %% [markdown]
# `conda --version`
#
# conda 4.7.12

# %% [markdown]
# ### Install/uninstall new packages with conda
# `conda install jupyter-lab pandas`

# %% [markdown]
# ### Review installed packages by conda
#
# `conda list`
#
# ```
# # Name                    Version                   Build  Channel
# asn1crypto                1.2.0                    py37_0
# ca-certificates           2019.10.16                    0
# certifi                   2019.9.11                py37_0
# cffi                      1.13.0           py37hb5b8e2f_0
# chardet                   3.0.4                 py37_1003
# conda                     4.7.12                   py37_0
# conda-package-handling    1.6.0            py37h1de35cc_0
# cryptography              2.8              py37ha12b0ac_0
# idna                      2.8                      py37_0
# libcxx                    4.0.1                hcfea43d_1
# libcxxabi                 4.0.1                hcfea43d_1
# libedit                   3.1.20181209         hb402a30_0
# libffi                    3.2.1                h475c297_4
# ncurses                   6.1                  h0a44026_1
# openssl                   1.1.1d               h1de35cc_3
# pip                       19.3.1                   py37_0
# pycosat                   0.6.3            py37h1de35cc_0
# pycparser                 2.19                     py37_0
# pyopenssl                 19.0.0                   py37_0
# pysocks                   1.7.1                    py37_0
# python                    3.7.4                h359304d_1
# python.app                2                        py37_9
# readline                  7.0                  h1de35cc_5
# requests                  2.22.0                   py37_0
# ruamel_yaml               0.15.46          py37h1de35cc_0
# setuptools                41.4.0                   py37_0
# six                       1.12.0                   py37_0
# sqlite                    3.30.0               ha441bb4_0
# tk                        8.6.8                ha441bb4_0
# tqdm                      4.36.1                     py_0
# urllib3                   1.24.2                   py37_0
# wheel                     0.33.6                   py37_0
# xz                        5.2.4                h1de35cc_4
# yaml                      0.1.7                hc338f04_2
# zlib                      1.2.11               h1de35cc_3
#
# ```
#
# Note: it allows to install packages with the help of pip but it may work improperly

# %% [markdown]
# ## Conda virtual env
# ### Choose necessary python entrepreter
#
#
# `conda search "^python$"`

# %%
# !conda search "^python$"
# Out:
# Loading channels: done
# # Name                       Version           Build  Channel
# python                        2.7.13     h32f5f24_13  pkgs/main
# python                        2.7.13     h89fad4f_16  pkgs/main
# python                        2.7.13     hdada7c8_15  pkgs/main
# python                        2.7.14     h001abdc_23  pkgs/main
# python                        2.7.14     h138c1fe_30  pkgs/main
# python                        2.7.14     h138c1fe_31  pkgs/main
# python                        2.7.14     h50fefbe_18  pkgs/main
# python                        2.7.14     ha6acbcf_22  pkgs/main
# python                        2.7.14     ha7e29e4_26  pkgs/main
# python                        2.7.14     hd74e306_15  pkgs/main
# python                        2.7.14     hde5916a_29  pkgs/main
# python                        2.7.14     he768d2d_19  pkgs/main
# python                        2.7.14     hed931fe_16  pkgs/main
# python                        2.7.15      h138c1fe_0  pkgs/main
# python                        2.7.15      h8f8e585_2  pkgs/main
# python                        2.7.15      h8f8e585_4  pkgs/main
# python                        2.7.15      h8f8e585_6  pkgs/main
# python                        2.7.16      h97142e2_0  pkgs/main
# python                        2.7.16      h97142e2_1  pkgs/main
# python                        2.7.16      h97142e2_2  pkgs/main
# python                        2.7.16      h97142e2_3  pkgs/main
# python                        2.7.16      h97142e2_4  pkgs/main
# python                        2.7.16      h97142e2_5  pkgs/main
# python                        2.7.16      h97142e2_6  pkgs/main
# python                        2.7.16      h97142e2_7  pkgs/main
# python                        2.7.17      h97142e2_0  pkgs/main
# python                        2.7.18      h47d645e_1  pkgs/main
# python                        2.7.18      hc817775_0  pkgs/main
# python                         3.5.4     h4bd9b1b_18  pkgs/main
# python                         3.5.4     h821eb87_14  pkgs/main
# python                         3.5.4     h8f450c2_22  pkgs/main
# python                         3.5.4     hb8880cc_19  pkgs/main
# python                         3.5.4     hc167b69_27  pkgs/main
# python                         3.5.4     hdd9bdb2_21  pkgs/main
# python                         3.5.4     he1de2d4_12  pkgs/main
# python                         3.5.4     he720263_23  pkgs/main
# python                         3.5.4     hf91e954_15  pkgs/main
# python                         3.5.5      h0a44026_3  pkgs/main
# python                         3.5.5      hc167b69_0  pkgs/main
# python                         3.5.5      hc167b69_1  pkgs/main
# python                         3.5.6      hc167b69_0  pkgs/main
# python                         3.6.2     h26d10c0_12  pkgs/main
# python                         3.6.2     h9e63aee_14  pkgs/main
# python                         3.6.2     ha11d96e_18  pkgs/main
# python                         3.6.2     hd04bb42_19  pkgs/main
# python                         3.6.2     hd0bf7f1_15  pkgs/main
# python                         3.6.3      h47c878a_7  pkgs/main
# python                         3.6.3      h5ce8c04_4  pkgs/main
# python                         3.6.3      h6804ab2_0  pkgs/main
# python                         3.6.3      h794556d_2  pkgs/main
# python                         3.6.3      hc655967_3  pkgs/main
# python                         3.6.4      hc167b69_0  pkgs/main
# python                         3.6.4      hc167b69_1  pkgs/main
# python                         3.6.4      hc167b69_3  pkgs/main
# python                         3.6.5      hc167b69_0  pkgs/main
# python                         3.6.5      hc167b69_1  pkgs/main
# python                         3.6.6      hc167b69_0  pkgs/main
# python                         3.6.7      haf84260_0  pkgs/main
# python                         3.6.8      haf84260_0  pkgs/main
# python                         3.6.9      h359304d_0  pkgs/main
# python                        3.6.10      h359304d_0  pkgs/main
# python                        3.6.10      hc70fcce_1  pkgs/main
# python                        3.6.10      hf48f09d_2  pkgs/main
# python                        3.6.10      hfe9666f_1  pkgs/main
# python                        3.6.12      h26836e1_2  pkgs/main
# python                        3.6.13      h88f2d9e_0  pkgs/main
# python                         3.7.0      hc167b69_0  pkgs/main
# python                         3.7.1      haf84260_3  pkgs/main
# python                         3.7.1      haf84260_7  pkgs/main
# python                         3.7.2      haf84260_0  pkgs/main
# python                         3.7.3      h359304d_0  pkgs/main
# python                         3.7.4      h359304d_0  pkgs/main
# python                         3.7.4      h359304d_1  pkgs/main
# python                         3.7.5      h359304d_0  pkgs/main
# python                         3.7.6      h359304d_2  pkgs/main
# python                         3.7.7 hc70fcce_0_cpython  pkgs/main
# python                         3.7.7      hf48f09d_4  pkgs/main
# python                         3.7.7 hfe9666f_0_cpython  pkgs/main
# python                         3.7.9      h26836e1_0  pkgs/main
# python                        3.7.10      h88f2d9e_0  pkgs/main
# python                         3.8.0      h359304d_0  pkgs/main
# python                         3.8.0      h359304d_1  pkgs/main
# python                         3.8.0      h359304d_2  pkgs/main
# python                         3.8.1      h359304d_1  pkgs/main
# python                         3.8.2      hc70fcce_0  pkgs/main
# python                         3.8.2     hf48f09d_13  pkgs/main
# python                         3.8.2      hfe9666f_0  pkgs/main
# python                         3.8.3      h26836e1_1  pkgs/main
# python                         3.8.3      h26836e1_2  pkgs/main
# python                         3.8.5      h26836e1_0  pkgs/main
# python                         3.8.5      h26836e1_1  pkgs/main
# python                         3.8.8      h88f2d9e_4  pkgs/main
# python                         3.8.8      h88f2d9e_5  pkgs/main
# python                        3.8.10      h88f2d9e_7  pkgs/main
# python                         3.9.0      h88f2d9e_1  pkgs/main
# python                         3.9.0      h88f2d9e_2  pkgs/main
# python                         3.9.1      h88f2d9e_2  pkgs/main
# python                         3.9.2      h88f2d9e_0  pkgs/main
# python                         3.9.4      h88f2d9e_0  pkgs/main
# python                         3.9.5      h88f2d9e_3  pkgs/main

# %% [markdown]
# ### Create conda virtual env
#
# `conda create -n local_env python=3.8 anaconda`
#
# `conda activate locl_env`

# %% [markdown]
# ## python interactive mode
#
# Run in terminal `python`
#
# ```
# $ python
# Python 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)] :: Anaconda, Inc. on darwin
# Type "help", "copyright", "credits" or "license" for more information.
# >>> print ('hello python')
# hello python
# >>> exit()
# $
# ```

# %% [markdown]
# ### Running script
# #### Create script

# %%
with open('hello.py', 'w') as f:
        f.write("print ('Hello SmartInsight')")

# %% [markdown]
# #### Review content

# %%
# !cat hello.py
# Out:
# print ('Hello SmartInsight')

# %% [markdown]
# #### Run the python file

# %%
# !python hello.py
# Out:
# Hello SmartInsight

# %% [markdown]
# ## Jupyter notebook
#
# ### Install with pip
# `pip install jupyter`
#
# ### Install with conda
# `conda install jupyter`
#
# ### Run jupyter
# `jupyter notebook`
#
# or with additional parameters e.g. to avoid token prompt and specify the port:
# <br>`jupyter notebook --no-browser --port=8890 --allow-root --ip=0.0.0.0 --NotebookApp.token='' --NotebookApp.password=''`
#
# Access it in browser e.g.:
# <br>http://10.252.0.18:8890/tree
#
# **Note**: You get jupyter notebook as component of Anaconda-Navigator

# %% [markdown]
# <!-- anaconda_navigator -->
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Launch Jupyter notebook on docker container
#
# 1) Install [docker](https://docs.docker.com/get-docker/)<br>
# 2) check docker ios running:  `docker -v` <br>
# 3) run command `docker run -it -p 8820:8888 -v "$(pwd):/work" oleksiytsebriy/data_science_env:v0` <br>
# **Note**: You will need to wait minute or two while it loads the image first time <br>
# 4) open in browser `http://localhost:8820/tree`
#
#
# Note:
# - convenient for reproducing and customization but requires more efforts to install new packages
# - kernel may restart due to lack of memory

# %% [markdown]
# ### Work in jupyter
# #### Modes
#     - view  (blue border)
#     - edit (green border)
# #### Cell types
#     - Code
#     - Mardown

# %% [markdown]
# This is Markdown cell (shortcut M in view mode)

# %%
# Code cell (shortcut Y in view mode)
2+3
# Out:
# 5

# %% [markdown]
# #### Execution
#     - executes code cell by cell (comfortable for experiments and demo)

# %%
a=3

# %%
a
# Out:
# 3

# %% [markdown]
# #### Run commands as in terminal
# use `!` at the begining

# %%
# !which python
# Out:
# /usr/local/bin/python

# %% [markdown]
# some commands are executable without `!`

# %%
ls
# Out:
# hello_world.py  lesson_1_working_environment.ipynb

# %% [markdown]
# #### Headings
#     - Heading 1,2,3,... formating with #, ##, ###,...

# %% [markdown]
# #### Support of html tags
#
# <font color= 'green' size= 6> color= green size= 6 </font>

# %% [markdown]
# #### Links
# [google](www.google.com.ua)

# %% [markdown]
# #### Images
#
#     Option 1: Make the cell of markdown type and just copy past the file as attachment
#     Option 2: Make the cell of markdown type
#         <img src = "img/matplotlib_layers.png" height=500 width= 500 align="left">
#     Option 3: keep the cell as code
#         %%html
#         <img src = "img/matplotlib_layers.png" height=500 width= 500 align="left">

# %% [markdown]
# ## jupyter lab
#
# `conda install jupyter-lab`
#
# If installed, run without `tree` in the url `http://localhost:8890/tree` or provide direct `lab` e.g.
# `http://localhost:8890/lab?`
#
# **Note:** Some functionality does not work in jupyter lab that works in jupyter notebook  and vice versa

# %% [markdown]
# <!-- jupyterlab -->
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Colab
#
# [run colab](https://colab.research.google.com/notebooks/intro.ipynb)
#
# Provided by google:
# - requires google account
# - minimum efforts to start
# - most necessary packages installed already
# - easy to share
# - access to google drive
# - gpu (free) available
#
# Note:
# - You will not have permanent files uploaded to colab, however you may use `wget` command
# - may run slower than on locval machine / server
# - may stop unexpectedly due to google need

# %% [markdown]
# <!-- colab -->
# ![image.png](attachment:image.png)

# %% [markdown]
# **Note:** You may use command wget to get file programatically file from net

# %%
# !wget https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fspecials-images.forbesimg.com%2Fdam%2Fimageserve%2F966248982%2F960x0.jpg%3Ffit%3Dscale -O img_wget_sample.png
# Out:
# Warning: Failed to set locale category LC_NUMERIC to en_UA.
# Warning: Failed to set locale category LC_TIME to en_UA.
# Warning: Failed to set locale category LC_COLLATE to en_UA.
# Warning: Failed to set locale category LC_MONETARY to en_UA.
# Warning: Failed to set locale category LC_MESSAGES to en_UA.
# --2021-05-24 18:51:21--  https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fspecials-images.forbesimg.com%2Fdam%2Fimageserve%2F966248982%2F960x0.jpg%3Ffit%3Dscale
# Resolving thumbor.forbes.com (thumbor.forbes.com)... 151.101.38.49
# Connecting to thumbor.forbes.com (thumbor.forbes.com)|151.101.38.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94595 (92K) [image/jpeg]
# Saving to: ‘img_wget_sample.png’
#
# img_wget_sample.png 100%[===================>]  92.38K  --.-KB/s    in 0.04s
#
# 2021-05-24 18:51:21 (2.29 MB/s) - ‘img_wget_sample.png’ saved [94595/94595]

# %% [markdown]
# <img src = "img_wget_sample.png" height=500 width= 500 align="left">

# %% [markdown]
# ## Pycharm
#
# Great for scripts development:
# - convenient editor
# - debug tools
# - work with environment variables
# - integrated with git
# - navigation through file system
# - integrated terminal
# - console
# - project structure
# - community version is free
#
#
#
#
# ## Add link to download

# %% [markdown]
# ## Environment on cloud
#
# Virtual machines on AWS/Google
# - in case of need of high performance
# - various computation plans offered
#
# Note:
# - Payment is required
#
# Will consider this environment at learning convolutional models

# %% [markdown]
# # todo
# python cources
#
# types
#
# list comperhensions

# %%
# read and save files

# %%
jupyter magic

# %%
summary
