# %% [markdown]
# # Probability  distribution function
# norm.pdf

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(1, 1)

x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)

ax.plot(x, norm.pdf(x),'r-', lw=5, alpha=0.6, label='norm pdf')

# %% [markdown]
# #### norm.ppf

# %%
# The method norm.ppf() takes a percentage and returns
# a standard deviation multiplier for what value that percentage occurs at.
norm.ppf(0.95), norm.ppf(0.95, loc=0, scale=1)

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
# plt.figure()
_, axes = plt.subplots(1, 3, figsize=(14,4))

x = np.linspace(-4,4, 100)
for i,s  in enumerate([1/2,1,2]):
    axes[i].plot(x, norm.pdf(x, 0,s),'r-', lw=3, alpha=0.6, label='norm pdf')
    axes[i].set_title(f'std={s}')

# %%
norm.pdf(0),norm.pdf(5)
# Out:
# (0.3989422804014327, 1.4867195147342979e-06)

# %% [markdown]
# ### Cumulative normal distribution
# Area

# %%
plt.figure()
plt.plot(x, norm.cdf(x),'b-', lw=5, alpha=0.6, label='cdf')

# %%
norm.cdf(0),norm.cdf(5)
# Out:
# (0.5, 0.9999997133484281)

# %% [markdown]
# ## Probability of specified normal distribution

# %%
# x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
norm.pdf(5, 5, 1) # mean = 5
# Out:
# 0.3989422804014327

# %%
norm.pdf(5, 0, 1)
# Out:
# 1.4867195147342979e-06

# %%
norm.pdf(0,0,1) # probability of 0 for mu =0 std = 1
# Out:
# 0.3989422804014327

# %%
help(norm.pdf)
# Out:
# Help on method pdf in module scipy.stats._distn_infrastructure:
#
# pdf(x, *args, **kwds) method of scipy.stats._continuous_distns.norm_gen instance
#     Probability density function at x of the given RV.
#
#     Parameters
#     ----------
#     x : array_like
#         quantiles
#     arg1, arg2, arg3,... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information)
#     loc : array_like, optional
#         location parameter (default=0)
#     scale : array_like, optional
#         scale parameter (default=1)
#
#     Returns
#     -------
#     pdf : ndarray
#         Probability density function evaluated at x

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %% [markdown]
# # manual implementation

# %%
def norm_pdf(x,mu, sigma):
    return np.exp( (-(x-mu)**2) / (2*sigma**2 )  )   / (sigma * np.sqrt(2* np.pi))

# %%
x, mu, sigma =0,0,1
norm.pdf(x, mu, sigma) , norm_pdf(x,mu, sigma)
# Out:
# (0.3989422804014327, 0.3989422804014327)

# %%
x, mu, sigma =5,0,1
norm.pdf(x, mu, sigma) , norm_pdf(x,mu, sigma)
# Out:
# (1.4867195147342979e-06, 1.4867195147342979e-06)

# %%
x, mu, sigma =5,0,2
norm.pdf(x, mu, sigma) , norm_pdf(x,mu, sigma)
# Out:
# (0.00876415024678427, 0.00876415024678427)
